# %%
import pandas as pd

# %%
A = pd.read_csv("c:/Users/91879/Downloads/Cars93.csv")

# %% [markdown]
# # Find out models of cars which have atleast 1 Airbag

# %%
A[A.AirBags != "None"]
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 5    6          Buick         Century  Midsize       14.2   15.7       17.3
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# 12  13      Chevrolet         Corsica  Compact       11.4   11.4       11.4
# ...

# %% [markdown]
# # Find out all 5 seater cars that are of compact type

# %%
A[(A.Type == "Compact") & (A.Passengers == 5)]
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 11  12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet   Corsica  Compact       11.4   11.4       11.4
# 32  33           Ford     Tempo  Compact       10.4   11.3       12.2
# 54  55          Mazda       626  Compact       14.3   16.5       18.7
# 57  58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9
# 64  65         Nissan    Altima  Compact       13.0   15.7       18.3
# 67  68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0
# 73  74        Pontiac   Sunbird  Compact        9.4   11.1       12.8
# 77  78           Saab       900  Compact       20.3   28.7       37.1
# 81  82         Subaru    Legacy  Compact       16.3   19.5       22.7
# 89  90     Volkswagen    Passat  Compact       17.6   20.0       22.4
# ...

# %%
pd.set_option("display.max_columns",50)

# %%
pd.set_option("display.max_rows",100)

# %% [markdown]
# # Fetch only car type and Price and sort that data based on both

# %%
A[["Type", "Price"]].sort_values(by=['Type', 'Price'], ascending=True)
# Out:
#        Type  Price
# 73  Compact   11.1
# 32  Compact   11.3
# 12  Compact   11.4
# 24  Compact   13.3
# 11  Compact   13.4
# 67  Compact   13.5
# 64  Compact   15.7
# 20  Compact   15.8
# 54  Compact   16.5
# 42  Compact   17.5
# 81  Compact   19.5
# 89  Compact   20.0
# 91  Compact   22.7
# 77  Compact   28.7
# 2   Compact   29.1
# 57  Compact   31.9
# 19    Large   18.4
# 17    Large   18.8
# 29    Large   19.3
# 70    Large   20.7
# 6     Large   20.8
# 37    Large   20.9
# 7     Large   23.7
# 76    Large   24.4
# 21    Large   29.5
# 9     Large   34.7
# 51    Large   36.1
# 46  Midsize   13.9
# 60  Midsize   14.9
# 26  Midsize   15.6
# 5   Midsize   15.7
# 14  Midsize   15.9
# 68  Midsize   16.3
# 85  Midsize   18.2
# 75  Midsize   18.5
# 36  Midsize   20.2
# 66  Midsize   21.5
# 62  Midsize   26.1
# 8   Midsize   26.3
# 92  Midsize   26.7
# 48  Midsize   28.0
# 4   Midsize   30.0
# 1   Midsize   33.9
# 50  Midsize   34.3
# 49  Midsize   35.2
# 3   Midsize   37.7
# ...

# %%
A

# %% [markdown]
# # Type wise average mileage on highway

# %%
A.groupby(by=["Type"])["MPG.highway"].mean()
# Out:
# Type
# Compact    29.875000
# Large      26.727273
# Midsize    26.727273
# Small      35.476190
# Sporty     28.785714
# Van        21.888889
# Name: MPG.highway, dtype: float64

# %% [markdown]
# # Find out Make of all USA based Sporty cars

# %%
A[(A.Type == "Sporty") & (A.Origin == "USA")][['Make', 'Type', 'Origin']]
# Out:
#                   Make    Type Origin
# 13    Chevrolet Camaro  Sporty    USA
# 18  Chevrolet Corvette  Sporty    USA
# 27       Dodge Stealth  Sporty    USA
# 33        Ford Mustang  Sporty    USA
# 34          Ford Probe  Sporty    USA
# 59       Mercury Capri  Sporty    USA
# 71      Plymouth Laser  Sporty    USA
# 74    Pontiac Firebird  Sporty    USA

# %% [markdown]
# # Find out the Manufacturer of the car having highest horsepower

# %%
A.sort_values(by=['Horsepower'], ascending=False)[0:1][['Manufacturer']]
# Out:
#    Manufacturer
# 18    Chevrolet

# %% [markdown]
# ## Find out car having highest Mileage in city

# %%
X = A['MPG.city'].max()
X
# Out:
# 46

# %%
A[A['MPG.city'] == X]
# Out:
#     id Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo  Metro  Small        6.7    8.4       10.0        46
#
#     MPG.highway AirBags DriveTrain Cylinders  EngineSize  Horsepower   RPM  \
# 38           50    None      Front         3         1.0          55  5700
#
#     Rev.per.mile Man.trans.avail  Fuel.tank.capacity  Passengers  Length  \
# 38          3755             Yes                10.6           4     151
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room  Luggage.room  Weight  \
# 38         93     63           34            27.5          10.0    1695
#
#      Origin       Make
# 38  non-USA  Geo Metro

# %% [markdown]
# ## Find out Models of cars which are having Price between 17 and 25

# %%
A[(A.Price>17)&(A.Price<25)][['Model']]
# Out:
#              Model
# 6          LeSabre
# 7       Roadmaster
# 17         Caprice
# 19        Concorde
# 25         Caravan
# 29          Vision
# 35        Aerostar
# 36          Taurus
# 37  Crown_Victoria
# 40         Prelude
# 42          Accord
# 55             MPV
# 65           Quest
# 66          Maxima
# 69      Silhouette
# 70    Eighty-Eight
# 74        Firebird
# 75      Grand_Prix
# 76      Bonneville
# 81          Legacy
# 84          Celica
# 85           Camry
# 86          Previa
# 88         Eurovan
# 89          Passat
# 90         Corrado
# 91             240

# %% [markdown]
# ## Find out top 7 most fuel economic cars for highway

# %%
A.sort_values(by=['MPG.highway'], ascending=False).head(7)
# Out:
#     id Manufacturer   Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo   Metro  Small        6.7    8.4       10.0        46
# 41  42        Honda   Civic  Small        8.4   12.1       15.8        42
# 82  83       Suzuki   Swift  Small        7.3    8.6       10.0        39
# 72  73      Pontiac  LeMans  Small        8.2    9.0        9.9        31
# 78  79       Saturn      SL  Small        9.2   11.1       12.9        28
# 83  84       Toyota  Tercel  Small        7.8    9.8       11.8        32
# 79  80       Subaru   Justy  Small        7.3    8.4        9.5        33
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 38           50         None      Front         3         1.0          55
# 41           46  Driver only      Front         4         1.5         102
# 82           43         None      Front         3         1.3          70
# 72           41         None      Front         4         1.6          74
# ...

# %% [markdown]
# ## Find out Models of cars having no AirBags and which are of compact type whose price is below 20.

# %%
A[(A.AirBags=='None')&(A.Type=='Compact')&(A.Price<20)][['Model']]
# Out:
#        Model
# 11  Cavalier
# 32     Tempo
# 67   Achieva
# 73   Sunbird

# %% [markdown]
# ## Find out top 7 most fuel economic cars for city, show results in sorted manner based on Horsepower

# %%
A.sort_values(by=['MPG.city'], ascending=False).head(7).sort_values(by='Horsepower', ascending=False)
# Out:
#     id Manufacturer    Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 41  42        Honda    Civic  Small        8.4   12.1       15.8        42
# 83  84       Toyota   Tercel  Small        7.8    9.8       11.8        32
# 72  73      Pontiac   LeMans  Small        8.2    9.0        9.9        31
# 79  80       Subaru    Justy  Small        7.3    8.4        9.5        33
# 82  83       Suzuki    Swift  Small        7.3    8.6       10.0        39
# 30  31         Ford  Festiva  Small        6.9    7.4        7.9        31
# 38  39          Geo    Metro  Small        6.7    8.4       10.0        46
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 41           46  Driver only      Front         4         1.5         102
# 83           37  Driver only      Front         4         1.5          82
# 72           41         None      Front         4         1.6          74
# ...

# %% [markdown]
# ## Find out Cars having mileage of more than 15 miles in city

# %%
A[A['MPG.city']>15]
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura         Integra    Small       12.9   15.9       18.8
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 5    6          Buick         Century  Midsize       14.2   15.7       17.3
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# ...

# %% [markdown]
# ## Find out Cars with US based origin

# %%
A[A.Origin=='USA'][['Model']]
# Out:
#              Model
# 5          Century
# 6          LeSabre
# 7       Roadmaster
# 8          Riviera
# 9          DeVille
# 10         Seville
# 11        Cavalier
# 12         Corsica
# 13          Camaro
# 14          Lumina
# 15      Lumina_APV
# 16           Astro
# 17         Caprice
# 18        Corvette
# 19        Concorde
# 20         LeBaron
# 21        Imperial
# 22            Colt
# 23          Shadow
# 24          Spirit
# 25         Caravan
# 26         Dynasty
# 27         Stealth
# 28          Summit
# 29          Vision
# 30         Festiva
# 31          Escort
# 32           Tempo
# 33         Mustang
# 34           Probe
# 35        Aerostar
# 36          Taurus
# 37  Crown_Victoria
# 50     Continental
# 51        Town_Car
# 59           Capri
# 60          Cougar
# 67         Achieva
# 68   Cutlass_Ciera
# 69      Silhouette
# 70    Eighty-Eight
# 71           Laser
# 72          LeMans
# 73         Sunbird
# 74        Firebird
# 75      Grand_Prix
# ...

# %% [markdown]
# ##  Find out Cars with no airbags and which are compact in type, from the output retrieve only Model, Mileage in city, Type, Airbags

# %%
A[(A.AirBags=='None')& (A.Type=='Compact')][['Model', 'MPG.city', 'Type', 'AirBags']]
# Out:
#        Model  MPG.city     Type AirBags
# 11  Cavalier        25  Compact    None
# 32     Tempo        22  Compact    None
# 67   Achieva        24  Compact    None
# 73   Sunbird        23  Compact    None
# 89    Passat        21  Compact    None

# %% [markdown]
# ## Find out cars with Mileage in city more than 15 which are compact in type.

# %%
A[(A['MPG.city']>15) & (A.Type=='Compact')][['Model','Type', 'MPG.city']]
# Out:
#        Model     Type  MPG.city
# 2         90  Compact        20
# 11  Cavalier  Compact        25
# 12   Corsica  Compact        25
# 20   LeBaron  Compact        23
# 24    Spirit  Compact        22
# 32     Tempo  Compact        22
# 42    Accord  Compact        24
# 54       626  Compact        26
# 57      190E  Compact        20
# 64    Altima  Compact        24
# 67   Achieva  Compact        24
# 73   Sunbird  Compact        23
# 77       900  Compact        20
# 81    Legacy  Compact        23
# 89    Passat  Compact        21
# 91       240  Compact        21
